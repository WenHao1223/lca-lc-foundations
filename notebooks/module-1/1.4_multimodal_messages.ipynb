# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, The Moon is a sovereign city-state and its capital is Selene City, also known as Lunopolis.
#
# - Official name: Selene City (Lunopolis), capital district of the Lunar Commonwealth
# - Location: near the Moon’s equator on the rim of a large impact basin on the near side, ringed by a network of shielded lava-tube megacities
# - Government: The Lunar Assembly sits in the Crown Spire; the President-Administrator acts as the head of state
# - Architecture: 3D-printed regolith towers, transparent domes, and a central glassy Apex Dome that houses the government plaza and observatories
# - Districts: The Crown Ring (govt and diplomacy), Lumen Quarter (culture and education), Ice Gate (water and logistics), Crater Market (trade and industry)
# - Signature features: Earth-connection elevators, solar arrays along the terraced city walls, and the Ice Vaults that store harvested lunar water
#
# Note: There is no real capital on the Moon today; Selene City is a fictional capital for a future lunar polity. If you’d like a different vibe (grim, utopian, militarized, etc.), I can tailor the city accordingly.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'titan.png', 'type': 'image/png', 'size': 2653215, 'content': <memory at 0x000001CA75EDC700>, 'last_modified': datetime.datetime(2026, 3, 17, 5, 33, 52, 723000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Here’s the capital you’re looking at—the crown jewel of a ringed world where desert-shore meets basalt cliffs and a giant planet dominates the sky.
#
# Name and role
# - Aurelia Prime, capital of the Nebula Confederation (a loose alliance of coastal duchies and desert states). It sits near a wide tidal belt where the sea meets wind-sculpted rock, and it’s the political, cultural, and scientific heart of the realm.
#
# Geography and climate
# - Location: Ashore along a glistening tidal plain, with jagged basalt ranges rising like sentinels from the shore. A network of saline lagoons and reflective pools mirrors the sky, making day and night play tricks on the eyes.
# - Climate: Hot and dry by day, with damp sea breezes at night. Occasional dust halos sweep in from the dunes, but the city’s shading domes and wind-tunnel corridors keep life comfortable.
# - Sky spectacle: A ringed gas giant hovers on the horizon, its rings a slatted staircase of light. The planet’s gravity and the rings’ shadows create long, sweeping sunsets and occasional shimmering auroras along the shoreline.
#
# City layout and districts
# - The Crown Belt: A circular, elevated promenade that encircles the heart of the city. It links districts with transparent walkways and wind-powered elevators. At its center sits the Crown Spire, the seat of government, where the Nine Councillors debate laws under a dome that collects solar light for a living mural.
# - Cliffside Hangers: Homes, workshops, and markets carved into and built against the basalt cliffs. Narrow stair-cases wind up the rock, and balconies overhang the sea, catching the spray of every wave.
# - The Salt Cathedral Quarter: A sacred-commercial district built into a cliff cave, its interiors lined with crystallized salt and bioluminescent algae. It hosts nightly performances of wind-chimes that double as public memory banks for local histories.
# - The Archive of Glass: A subterranean complex of data halls and crystal libraries. Shelves are made of smart glass that responds to touch, revealing records in layers of color and sound.
# - The Ring Gardens: A belt of bioglass-domes and vertical farms, fed by seawater condensers and solar luminaires. It’s both a sanctuary and a research campus, famous for flora that thrives on mineral-rich desert air.
# - Port of Tides: A bustling harbor where ships and wind-sailers dock. The water is brackish, and canals weave through the ships, bringing goods from both coast and cliff.
#
# Architecture and aesthetics
# - Materials: Basalt black as night, copper-gold facades that shimmer with heat, and living glass that tints itself to the sun’s angle. Buildings are interwoven with grain-like wooden frames grown from hard desert timber.
# - Style: A fusion of sculpture and utility. Buildings resemble carved monoliths; their exteriors host terraces, wind arches, and ring-shaped railings that echo the planet’s rings. Light is a material here: solar sails power street-lamps that hang from above, and water-circuits shimmer in the streets at night.
# - Signature features: Water channels lined with reflective panels to amplify daylight for indoor farming; wind-turbine towers shaped like sea-shells; terraces planted with salt-tolerant flora that glow faintly at dusk.
#
# Society and culture
# - Inhabitants: The Marrow, a diverse mix of desert nomads, cliff-dwellers, and scholars from the coastal markets. They’re known for hospitality, engineering prowess, and a ritual of “speaking with light”—a form of performance poetry where words are translated into colored light on living glass.
# - Language and learning: A bilingual culture—one oral tradition passed in caravan courts, and one symbolic language used within the Archive and the Salt Cathedral that encodes histories in shifting patterns of light and sound.
# - Festivals: The Ringing of the Tides (a procession that travels around the Crown Belt with light-sails pulsing in time to the planet’s rings) and the Night of Lantern Sands (where the gardens glow with bio-luminescent flora and memory-records are read aloud in the Salt Cathedral).
# - Economy and tech: A hybrid of trade city and research hub. Trade is dominated by high-value electronics, saline minerals, and water-concentration tech. Green tech—solar sails, wind-harvesters, and bio-domes—drives daily life and export.
#
# Politics and history
# - Government: The Nine Councillors (one from each major district) govern through consensus, with a rotating Governor who leads during crises. The Crown Spire houses their deliberations, visible to all via light-echo mirrors that project into the streets.
# - History: Founded after a great drought forced collaboration between desert and coast. A pact known as the Tide-and-Stone Accord created Aurelia Prime as a shared capital, a place where the harshness of the dunes and the mercy of the sea could coexist under the same sky.
# - Current themes: Sustainability vs. growth, preservation of memory, and the tension between secrecy (within the Archive) and openness (in the public square along the Crown Belt).
#
# Key landmarks and sights
# - The Crown Spire: The political heart. A towering, luminescent monument whose interior walls tell the city’s stories in a rotating mural of light and sound.
# - The Ring Gardens: The city’s green lungs, where research and culture mingle and visitors ride along elevated, circular paths.
# - The Salt Cathedral: A cavernous chapel and public hall with salt-crystal formations that resonate like wind chimes when the rings align in a particular way.
# - The Archive of Glass: A cavernous subterranean library where records are stored in multi-layered crystal grids; visitors can “read” histories by shifting the light angles.
# - The Gate of Tides: A monumental gate facing the sea, carved with reliefs of legends about how water and wind shaped the city.
#
# Life in Aurelia Prime
# - Daily rhythm: Morning markets along the Port of Tides, mid-day shade breaks in the Ring Gardens, evenings at the Salt Cathedral for ritual light performances, late nights in the Archive where scholars debate new discoveries.
# - Transportation: Compact hover-scooters on the street-level lanes, wind-sail shuttles along the Crown Belt, and subterranean trains that run beneath the cliff-face to avoid the heat.
# - Etiquette: Guests are welcomed with a glass of the local saline beverage; conversations often begin with a shared memory readout—the light-based memories stored in the glass architecture.
#
# Story hooks and ideas
# - A dispute over water rights between the coastal merchants and the inland desert communities could trigger a political crisis in the Crown Spire.
# - A researcher discovers a new memory pattern in the Archive that reveals a hidden treaty with beings from another world—perhaps a ringed planet’s shadow holds more than beauty.
# - A festival performance goes wrong when a light-speculates in the Ring Gardens reveals a past that someone wanted to forget.
#
# If you want, I can tailor Aurelia Prime to fit a specific plot, culture, or technological level. Tell me the vibe you’re after—grim political intrigue, hopeful frontier utopia, or a mystery set in the Archive—and I’ll tune the city’s details to match.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.88it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The audio file sounds like someone speaking softly or whispering. The voices are quiet and may be a person or people having a conversation in a low tone. There isn’t much background noise, but it is difficult to distinguish the exact words spoken because of the low volume and the clarity of the speech.
#
# Let me know if you would like me to listen again for more details or if you have any specific questions about it.
