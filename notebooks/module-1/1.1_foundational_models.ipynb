# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon has no government or sovereign status, so it doesn’t have a capital. If and when humans establish settlements there, any “capital” would depend on who administers the settlement and under what international agreements. Want me to invent a fictional capital for a story or discuss how a lunar governance could work?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 716, 'prompt_tokens': 13, 'total_tokens': 729, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEmcEHTOwqh5PLygEiVuEAPfWkVt', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf9b2-99ad-7a61-b602-c843321ebd3e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 716, 'total_tokens': 729, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon has no government or sovereign status, so it doesn’t have a capital. If and when humans establish settlements there, any “capital” would depend on who administers the settlement and under what international agreements. Want me to invent a fictional capital for a story or discuss how a lunar governance could work?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DKEmcEHTOwqh5PLygEiVuEAPfWkVt',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 716,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 640,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 729}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. In fiction some authors imagine lunar cities like Lunopolis or Luna City, but those are just invented. If you had a different angle in mind (e.g., a joke or a specific sci‑fi work), tell me and I can tailor it.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1434, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
# -> 1434     _handle_anthropic_bad_request(e)
#    1435 return self._format_output(data, **kwargs)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1432, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1430 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1431 try:
# -> 1432     data = self._create(payload)
#    1433 except anthropic.BadRequestError as e:
#    1434     _handle_anthropic_bad_request(e)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1286, in ChatAnthropic._create(self, payload)
#    1284 if "betas" in payload:
#    1285     return self._client.beta.messages.create(**payload)
# -> 1286 return self._client.messages.create(**payload)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\wenhlim8\Desktop\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1137, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134             err.response.read()
#    1136         log.debug("Re-raising status error")
# -> 1137         raise self._make_status_error_from_response(err.response) from None
#    1139     break
#    1141 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CZ7u4kVcSVSYyEZQakTZL'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question! The Moon doesn't have a capital city like Earth does. It's a natural satellite, not a country or a political entity.
#
# So, there's no "capital of the Moon."

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="gpt-5-nano")

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='a9d14ad7-588e-477d-a196-9c6504f3909b'),
#               AIMessage(content='There isn’t one. The Moon has no government or cities, so it has no capital. If you’re imagining a fictional world, you could invent a capital with a name like Lunapolis or Selene City.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 628, 'prompt_tokens': 13, 'total_tokens': 641, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKEvKcoNPCYUlHDORP2xcZblcdHyd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cf9ba-d8b1-7b61-85b4-067827eff0ac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 628, 'total_tokens': 641, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. If you’re imagining a fictional world, you could invent a capital with a name like Lunapolis or Selene City.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='561fbaaf-19f8-40de-90f1-ac9c36aa40c0'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='a03eebbc-cab0-46d2-ab74-cfac00ec5828', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='ca662824-19e4-4439-868d-7e051cd003fe'),
#               AIMessage(content='There isn’t a real capital of the Moon, of course—the Moon doesn’t have a government. Luna City is a fictional concept, but I can give you a rich, plausible world-building version you can use in stories or games.\n\nOverview\n- Luna City is the lunar capital of a future Earth–Moon federation. It’s a dense, multi-dome metropolis built into and around a shielded lava tube near the Moon’s equator on the near side, with a smaller orbital complex serving as a gateway to deeper space.\n\nLocation and layout\n- Location: near the equator on the Moon’s near side for easy Earth comms, logistics, and viewing of Earth from some districts.\n- Core geography: the city sits in and around a long lava-tube system. The main administrative core is inside a huge, pressurized crater ring, with outer districts expanding into surface domes and hover-tram corridors.\n- Districts (from center outward):\n  - Administrative Quarter: government offices, courts, archives, and the mayor’s mansion.\n  - Scientific Quarter: lunar university, research labs, telescopes and observatories, and mission control for lunar operations.\n  - Engineering and Industry Belt: power plants, life-support factories, 3D-printing hubs, mining and processing facilities.\n  - Cultural Quarter: museums, theaters, galleries, music venues, and lunar heritage spaces.\n  - Market and Port District: trade hubs, markets, hotels, restaurants, and the transit hubs that connect to orbit and other colonies.\n  - Residential Rings: housing for workers, researchers, and families, with parks and vertical farms.\n\nGovernance and society\n- Government: a parliamentary-like federation with a Luna City Council, an elected Mayor, and specialized ministries (Resources, Science, Security, Culture). A rotating interplanetary liaison council handles Earth-Mederation relations.\n- Inhabitants: a diverse mix of humans and android-assisted humans, scientists, miners, engineers, healthcare workers, educators, and artists. Many communities maintain a strong civic culture, with annual festivals tied to lunar cycles, Earth holidays, and lunar anniversaries.\n- Daily life things to know: life support and hydroponics are ubiquitous; gravity is about 1/6g, so movement looks deliberate and floatsy at first. Water ice and mineral resources are precious, so recycling and safety protocols are deeply ingrained.\n\nTechnology and architecture\n- Energy: solar farms on the surface paired with compact nuclear microreactors and in-situ resource utilization (ISRU) for water electrolysis and oxygen. Helium-3 is mined but mostly reserved for export contracts.\n- Construction: 3D-printed regolith bricks, inflatable habitats, and dome skylights made from strong transparent composites. Shields and regolith shielding protect residential layers from radiation.\n- Transportation: maglev or vacuum-tube transit between districts; short-range rovers for surface duty; elevators and airlocks connect surface to subterranean sections. In some districts, magnetic levitation streetcars glide above ground bridges to minimize dust intrusion.\n- Environment management: dust control via air curtains in corridors, airlocks at every transition, and subterranean parks with controlled microclimates.\n\nEconomy and culture\n- Economy: multi-planetary trade hub. Key industries include mining of rare lunar volatiles, life-support and materials manufacturing, lunar tourism, and R&D in space agriculture and robotics.\n- Culture: a blend of Earth traditions adapted to lunar life. Public art emphasizes resilience, science, and memory of Earth. Festivals celebrate lunar phases, Earth anniversaries, and interplanetary cooperation.\n- Landmarks and spaces: the Dawn Spire (a memorial and weather-control-looking tower), the Lumen Archive (digital and physical archives of lunar history), Moon Gate Plaza (opening to visitors and dignitaries), and The Echo Market (underground bazaar with holographic stalls).\n\nChallenges and ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital of the Moon, imagined for a hard sci‑fi or space opera setting. It’s a bustling, highly engineered hub that serves as the political, cultural, and economic heart of lunar civilization. Here’s a comprehensive picture you can drop into a story, game, or world bible.
#
# Overview
# - Name: Luna City
# - Status: Capital of the Moon within a lunar polity (e.g., Lunar Federation, Lunar Confederation, or a similar federation depending on your universe)
# - Population: Roughly 2–3 million residents and workers in a mature setting; grows with lunar industry and trade
# - Role: Seat of government, major research institutions, financial center, cultural capital, and gateway to the rest of the Moon and Earth
# - Style: A blend of fortress‑like efficiency and glassy, artful dome architecture reflecting life under a vacuum world
#
# Location and geography
# - Location: Near the southern polar region, at the rim of a large crater with access to subsurface ice and stable shadowed areas for resources. A second common option is the equatorial belt for easier solar access and rail links.
# - Terrain: Mostly built on reinforced crater rims, hollowed-out lava tubes, and large underground chambers to shield from radiation and micrometeoroids. Surface domes cover key districts; subterranean rings extend deeper into the crust.
# - Climate and environment: No natural atmosphere; life support is entirely mechanical. Surface temperature swings are brutal, so the city is enclosed and climate-controlled. Radiation shielding is a constant design constraint.
#
#  governance and society
# - Government: A federal or semi‑federal lunar government with:
#   - The Lumen Assembly (legislature) or Lunar Parliament
#   - The City Council (executive and municipal governance)
#   - A Lunar Security Directorate (law, order, space traffic)
#   - Various ministries (Energy, Resources, Health, Education, Culture, Infrastructure)
# - Symbol and culture: A unifying emblem blends a crescent with a forward‑pointing star; civic life emphasizes collaboration between Earth and Moon communities, intercolonial relations, and a strong sense of frontier identity.
# - Law and order: A mixed civilian‑military police structure specialized for closed‑environment living, with strong emergency response networks and strict dust and contamination controls.
#
# Districts and landmarks
# - The Citadel Dome Quarter: The political heart, housing the Lumen Assembly, council chambers, and the Grand Atrium. It’s a monument to resilience, with layered security and transparent public spaces.
# - The Ice Gate and Waterworks District: Centers for ice mining, water processing, and air‑water recycling facilities. Glazed facades reveal interior hydroponic gardens visible from the street.
# - The Helix District (research and innovation): A cluster of universities, biotech labs, and the Helix Research Complex, famous for life‑support technology, closed‑loop ecosystems, and lunar geology studies.
# - The Foundry Ring: Manufacturing and heavy industry, including 3D printing, regolith processing, and large‑scale 3D‑printed habitats. A network of robotic arms and automated assembly lines hum day and night.
# - The Skyglass Market and Plaza: Public squares under transparent domes, with markets, cafes, and performances that blend Earth cultures with lunar artistry. Night markets glow with bioluminescent flora and reflective metals.
# - The Orbital Gateway: A transport hub and spaceport connecting Luna City to Earth, lunar orbit stations, and other colonies. Includes passenger ferries, freighters, and emergency corridors to space.
# - The Quiet Slope Residential Hills: Families and workers live in gradually terraced neighborhoods that slope down from the rim to the subterranean layers. Green courtyards, low gravity parks, and vertical farms define daily life here.
# - The Dark-Side Observatory: A research outpost on the far side or shielded from Earth’s radio noise, enabling radio astronomy, SETI-style research, and planetary defense sensors.
#
# Technology and infrastructure
# - Life support: Closed‑loop air and water recycling, oxygen generation from water electrolysis, and robust filtration to handle lunar dust (regolith).
# - Power: A mix of solar arrays (on crater rims and domes with energy storage) and compact nuclear or fission reactors for baseline power. Redundancy and shielding are standard.
# - Housing and construction: Regolith‑based bricks, 3D‑printed alloys, lunar concrete, and ceramic composites. Many buildings use curved, aerodynamic forms to shed dust and resist micrometeoroids.
# - Gravity and health: The Moon’s 1/6 g means long‑term health care includes countermeasures against muscle atrophy and bone loss; some facilities leverage rotating sections to simulate 1 g for certain corridors or zones.
# - Transportation:
#   - Surface transit: All‑terrain maglev lines, hopper shuttles, and autonomous rovers for last‑mile travel.
#   - Vertical and horizontal linkages: Elevator‑like transit nodes between surface domes and subterranean layers; airlock corridors connect to the grid.
#   - Space access: Frequent transport to Earth and orbit via the Orbital Gateway; emergency shuttles for rapid evacuation.
# - Communication: High‑bandwidth optical networks inside the city; radio and laser links to Earth and other colonies; censored or secure channels for sensitive government data.
#
# Economy and resources
# - Primary sectors:
#   - Water ice mining and processing for life support and industry
#   - Helium‑3 and rare‑earth element extraction from the regolith
#   - 3D printing and in‑situ manufacturing for habitats and tools
#   - Agriculture and hydroponics for food security
#   - Tourism and culture (museum, observatories, lunar‑sky programs)
# - Currency and trade: A lunar credit or “Luna” used across lunar settlements; Earth–Moon trade in data services, mining outputs, and advanced materials.
# - Challenges: Dependence on Earth for certain supplies, transport costs, radiation shielding costs, and the need to secure enough water and energy to sustain growth.
#
# daily life and culture
# - Living conditions: Families and professionals live in placed sectors with shared recreational spaces, lunar gardens, and education facilities. Quiet hours emphasize mental health and family time within near‑zero‑gravity spaces.
# - Education: The Lunar City University and several specialized institutes, focusing on life support engineering, astrogeology, radiation protection, agriculture, and autonomous systems. Public education emphasizes safety, dust mitigation, and space ethics.
# - Arts and entertainment: Lunar art emphasizes reflection on Earth‑Moon ties, the beauty of 1/6 g motion, and the stark aesthetics of domed cities. Theatres use holographic and projection technologies; music blends Earth genres with lunar soundscapes created by gravity‑aware composers.
# - Cuisine: Hydroponic greens, algae proteins, lab‑grown meats, and lunar‑colony specialties. Dishes highlight the contrast between Earth’s abundance and lunar resourcefulness.
# - Religion and philosophy: A pluralistic society with chapels, meditation rooms, and interfaith centers; philosophy often centers on humanity’s role in a solar system of small worlds and the ethics of living off Earth’s cradle.
#
# Science, research, and exploration
# - Key institutions: Helix Research Complex, Lunar Observatory Network, and several field labs within the Ice Gate and subterranean valleys.
# - Focus areas:
#   - Closed‑loop life support and regenerative agriculture
#   - In‑situ resource utilization (ISRU) technologies
#   - Lunar geology, seismic activity, and mining engineering
#   - Astrobiology analog studies and radiation biology
# - Collaboration: Partnerships with Earth universities, private space companies, and international lunar programs. Data sharing is common but security measures govern sensitive breakthroughs.
#
# Security, health, and safety
# - Health facilities: Advanced clinics and a lunar hospital network that relies on telemedicine from Earth and on‑site specialists. Medical research includes zero‑gravity physiology and radiation protection.
# - Safety protocols: Rigorous dust control; airlocks with decontamination; emergency shelters and radiation storms with automatic sheltering and power backups.
# - Disaster response: Rapid evacuation protocols to underground safe zones, with contingency power and water supplies. Military or civilian security forces coordinate with emergency agencies.
#
# History and milestones (creative timeline)
# - Early colony era: Initial settlement focused on survival—habitat domes, water extraction, and basic life support.
# - The unification era: A political movement leads to a Lunar Covenant, creating a centralized capital city to unify lunar settlements.
# - The age of nets of trade: Luna City becomes a hub for Earth–Moon commerce, research, and governance, attracting diverse communities.
# - The green era: Widespread vertical farming and ISRU improvements boost resilience and reduce dependence on Earth.
# - Current era: Luna City stands as a mature capital with sprawling districts, advanced infrastructure, and a culture of cooperation between Earth and Moon.
#
# Story prompts and variations
# - A political crisis tests the Lunar Covenant during a dust storm and power shortage. How does Luna City adapt governance and keep the grid running?
# - An Earth–Moon trade delegation discovers a latent resource in a newly explored lava tube; tensions rise over ownership and access.
# - A cultural festival in the Skyglass Market reveals tensions between tradition and modernization as new technologies reshape daily life.
# - A research scandal at the Helix District sparks debates about data integrity and transparency across lunar science.
# - A near‑collision in space forces Luna City to coordinate with Earth and other colonies for a rapid response.
#
# If you want, I can tailor Luna City to a specific genre (hard sci‑fi realism, cyberpunk feel, space fantasy, YA adventure, etc.), era, or map layout. Tell me the tone, tech level, and political backdrop you prefer, and I’ll adapt the city’s geography, institutions, and key landmarks accordingly.
