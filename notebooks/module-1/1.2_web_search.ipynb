# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time access to events or releases after that unless your environment provides browsing capabilities and you enable them. If you need the latest information, you can share a link or allow me to browse (if available), and I can fetch and summarize current sources. In the meantime, I can help with anything up to mid-2024 and with analyzing new data you provide. What would you like to know?

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured ...",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8674071,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco,',
#    'score': 0.82391036,
#    'raw_content': None},
#   {'url': 'https://www.theguardian.com/us-news/2024/nov/07/san-francisco-mayor-election',
#    'title': 'Levi Strauss heir Daniel Lurie elected mayor of San ...',
#    'content': '... San Francisco non-profit he founded. He defeated several Democratic challengers, including the current mayor, London Breed, in an election',
#    'score': 0.8173562,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor',
#    'content': 'Mayor Daniel Lurie. We are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.',
#    'score': 0.8088086,
#    'raw_content': None},
#   {'url': 'https://www.latimes.com/california/story/2025-04-14/the-vibe-shift-is-real-as-san-francisco-mayor-daniel-lurie-becomes-hometown-hype-man',
#    'title': "Daniel Lurie is San Francisco's nerdy new mayor",
#    'content': "'There's a sense of hope and optimism people haven't seen in a long time,' San Francisco Mayor Daniel Lurie said of the city's nascent",
#    'score': 0.77548623,
#    'raw_content': None}],
#  'response_time': 0.79,
#  'request_id': '28ba1b0f-eb77-4ff9-b3eb-1f6f6f791b59'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='b2927595-c95e-473b-bb5e-296f213ae4ab'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 222, 'prompt_tokens': 133, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKHAGTCaU1mNity6Qel1Bsepztj17', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa3e-48de-7280-b7d9-eec8419cbf53-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2026'}, 'id': 'call_WZ7S1AYlLbHj0JyhyLcy9MRP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 222, 'total_tokens': 355, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2026", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.ktvu.com/news/sf-mayor-reflects-year-draws-close", "title": "Lurie reflects on first year in office as 2025 draws to a close - KTVU", "content": "Mayor Daniel Lurie is touting a transformational year, saying San Francisco has turned the corner and better things await the city in 2026.", "score": 0.84246206, "raw_content": null}, {"url": "https://sfstandard.com/2026/01/15/san-francisco-daniel-lurie-state-of-the-city/", "title": "Daniel Lurie was the public safety mayor. Now he\'s trying to be the ...", "content": "Mayor Daniel Lurie placed much of the focus of his first State of the City speech on making San Francisco accessible to working people,", "score": 0.7950386, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=LvoD21z_inM", "title": "Mayor Daniel Lurie\'s State of the City 2026 - YouTube", "content": "Watch San Francisco\'s Mayor Daniel Lurie give his State of the City address.", "score": 0.7823471, "raw_content": null}, {"url": "https://www.instagram.com/reel/DTQzoW3EnSv/", "title": "San Francisco, it\'s been an honor to serve as your mayor this first ...", "content": "... likes, 571 comments - danielluriesf on January 8, 2026: \\"San ... In his first State of the City address, Mayor Daniel Lurie chose a", "score": 0.7823471, "raw_content": null}, {"url": "https://www.sfchronicle.com/sf/article/daniel-lurie-lays-out-sf-road-map-in-state-of-city-21286425.php", "title": "Daniel Lurie lays out 2026 road map for S.F.: \'I will not back down\'", "content": "Mayor Daniel Lurie focused on trying to make San Francisco more affordable and delivering structural change at City Hall that makes the", "score": 0.7625837, "raw_content": null}], "response_time": 0.8, "request_id": "3acdf2ec-e438-46f4-aa0e-3a1df22dea4e"}', name='web_search', id='59cb0042-06a5-4410-8470-79d2f4be36bd', tool_call_id='call_WZ7S1AYlLbHj0JyhyLcy9MRP'),
#  AIMessage(content='As of January 2026, the current mayor of San Francisco is Daniel Lurie.\n\nIf you’d like, I can pull official city sources or more recent news to confirm the current status or provide more details about his term.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 952, 'prompt_tokens': 714, 'total_tokens': 1666, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKHALmfxbEKTNqEhPf2kTX3mWnL39', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cfa3e-5f67-7890-adad-ce8149af6ed3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 714, 'output_tokens': 952, 'total_tokens': 1666, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
