# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='d0f2ecaa-62f4-4080-a090-dcc0eab74a63'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 914, 'prompt_tokens': 1229, 'total_tokens': 2143, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKHr9oqbqavdtmyB2qJnwGBp6ssP8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa66-dd17-7d53-af22-c0e606750dc0-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2026', 'departureDateFlexRange': 0, 'passengers': {'adults': 1, 'children': 0, 'infants': 0}, 'cabinClass': 'M', 'sort': 'price', 'curr': 'USD', 'locale': 'en'}, 'id': 'call_8PfLC7sQWg8qWGjBJgwATW3c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1229, 'output_tokens': 914, 'total_tokens': 2143, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               ToolMessage(content=[{'type': 'text', 'text': '[\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T10:15:00.000Z",\n      "local": "2026-04-02T19:15:00.000"\n    },\n    "totalDurationInSeconds": 139500,\n    "durationInSeconds": 139500,\n    "price": 685,\n    "deepLink": "https://on.kiwi.com/1lQUvI",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T01:55:00.000Z",\n          "local": "2026-04-02T09:55:00.000"\n        }\n      },\n      {\n        "at": "AOJ",\n        "city": "Aomori",\n        "cityCode": "AOJ",\n        "arrival": {\n          "utc": "2026-04-02T05:20:00.000Z",\n          "local": "2026-04-02T14:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T08:50:00.000Z",\n          "local": "2026-04-02T17:50:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T06:55:00.000Z",\n      "local": "2026-04-02T15:55:00.000"\n    },\n    "totalDurationInSeconds": 127500,\n    "durationInSeconds": 127500,\n    "price": 759,\n    "deepLink": "https://on.kiwi.com/SncYrK",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T22:45:00.000Z",\n          "local": "2026-04-02T06:45:00.000"\n        }\n      },\n      {\n        "at": "OKA",\n        "city": "Okinawa Island",\n        "cityCode": "OKA",\n        "arrival": {\n          "utc": "2026-04-02T00:15:00.000Z",\n          "local": "2026-04-02T09:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T04:15:00.000Z",\n          "local": "2026-04-02T13:15:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "HND",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T19:30:00.000Z",\n      "local": "2026-03-31T12:30:00.000"\n    },\n    "arrival": {\n      "utc": "2026-04-02T06:50:00.000Z",\n      "local": "2026-04-02T15:50:00.000"\n    },\n    "totalDurationInSeconds": 127200,\n    "durationInSeconds": 127200,\n    "price": 768,\n    "deepLink": "https://on.kiwi.com/AjzE0w",\n    "currency": "USD",\n    "layovers": [\n      {\n        "at": "TPE",\n        "city": "Taipei",\n        "cityCode": "TPE",\n        "arrival": {\n          "utc": "2026-04-01T09:20:00.000Z",\n          "local": "2026-04-01T17:20:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-01T22:45:00.000Z",\n          "local": "2026-04-02T06:45:00.000"\n        }\n      },\n      {\n        "at": "OKA",\n        "city": "Okinawa Island",\n        "cityCode": "OKA",\n        "arrival": {\n          "utc": "2026-04-02T00:15:00.000Z",\n          "local": "2026-04-02T09:15:00.000"\n        },\n        "departure": {\n          "utc": "2026-04-02T04:20:00.000Z",\n          "local": "2026-04-02T13:20:00.000"\n        }\n      }\n    ]\n  },\n  {\n    "flyFrom": "SFO",\n    "flyTo": "NRT",\n    "cityFrom": "San Francisco",\n    "cityTo": "Tokyo",\n    "departure": {\n      "utc": "2026-03-31T23:45:00.000Z",\n      "local": "2026-03-31T16:45:00.000"\n    },\n    "arrival": {\n      "utc": "2026-0 ...
#               AIMessage(content='Here’s the direct flight I found for you:\n\nCheapest options\n| Route | Times (local) | Cabin | Price | Book |\n|---|---|---|---|---|\n| San Francisco SFO → Tokyo Narita NRT | 31/03 16:45 → 01/04 20:00 (11h 15m) | Economy | 789 USD | https://on.kiwi.com/9fgW4U |\n\nRecommendation: This is the only direct option on March 31st in the search results, and it’s the cheapest direct choice at 789 USD.\n\nHave a wonderful trip! Fun fact: Tokyo is famous for its cherry blossoms in spring, with peak bloom often around late March to early April in many years.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4136, 'prompt_tokens': 7129, 'total_tokens': 11265, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 3968, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKHrP3s5p23z8KZTT7sZKUO2XP4oc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cfa67-1a93-7f21-bbcc-09018b600965-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7129, 'output_tokens': 4136, 'total_tokens': 11265, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 3968}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here’s the direct flight I found for you:
#
# Cheapest options
# | Route | Times (local) | Cabin | Price | Book |
# |---|---|---|---|---|
# | San Francisco SFO → Tokyo Narita NRT | 31/03 16:45 → 01/04 20:00 (11h 15m) | Economy | 789 USD | https://on.kiwi.com/9fgW4U |
#
# Recommendation: This is the only direct option on March 31st in the search results, and it’s the cheapest direct choice at 789 USD.
#
# Have a wonderful trip! Fun fact: Tokyo is famous for its cherry blossoms in spring, with peak bloom often around late March to early April in many years.
