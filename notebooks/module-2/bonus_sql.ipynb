# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='48852d7d-0ebe-48dc-997b-66709e5924e9'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 880, 'prompt_tokens': 142, 'total_tokens': 1022, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjFce4Yr3fA3aJUDb3mDNCwvwqm', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa9a-07f8-7843-9054-9d1e6bc3c2f8-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM artists WHERE (name LIKE 'S%' OR name LIKE 's%') ORDER BY popularity DESC LIMIT 1;"}, 'id': 'call_hRRaKiJV9pyLCs6xL2aWooJX', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 142, 'output_tokens': 880, 'total_tokens': 1022, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such table: artists\n[SQL: SELECT name FROM artists WHERE (name LIKE 'S%' OR name LIKE 's%') ORDER BY popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='cfd44a21-419f-4c9d-9ad5-ed9f7d642d46', tool_call_id='call_hRRaKiJV9pyLCs6xL2aWooJX'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 232, 'prompt_tokens': 261, 'total_tokens': 493, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjMUAiIjhRoMyLxAy72VKL8N5zh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa9a-25b0-72f1-8205-00f5dadaf5c6-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';"}, 'id': 'call_jG34s4GRQ330MC2N0UCGJvOG', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 261, 'output_tokens': 232, 'total_tokens': 493, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='2e435c9a-1681-475d-b31a-f06c4beba990', tool_call_id='call_jG34s4GRQ330MC2N0UCGJvOG'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 354, 'total_tokens': 397, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjPCDY18yfgZNsaAZQnOWNkgfbP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa9a-3083-72e1-ad42-380addae3900-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM Artist WHERE (Name LIKE 'S%' OR Name LIKE 's%') ORDER BY Popularity DESC LIMIT 1;"}, 'id': 'call_Zog8Pi3CrPLGcK145e8c89lW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 354, 'output_tokens': 43, 'total_tokens': 397, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="Error: (sqlite3.OperationalError) no such column: Popularity\n[SQL: SELECT name FROM Artist WHERE (Name LIKE 'S%' OR Name LIKE 's%') ORDER BY Popularity DESC LIMIT 1;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)", name='sql_query', id='c7b70d92-b323-4ddd-934f-5454bd4fc7d8', tool_call_id='call_Zog8Pi3CrPLGcK145e8c89lW'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 476, 'total_tokens': 499, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjQEvP8lZjeHz04Pq2IV7UFrFHe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa9a-3627-7c51-b4d6-88825b2b38e5-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'PRAGMA table_info(Artist);'}, 'id': 'call_w4NEjMOuEht8FsSen6Kt52Og', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 476, 'output_tokens': 23, 'total_tokens': 499, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[(0, 'ArtistId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(120)', 0, None, 0)]", name='sql_query', id='693d8800-171b-4c7f-ba53-128514d4dcdd', tool_call_id='call_w4NEjMOuEht8FsSen6Kt52Og'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 865, 'prompt_tokens': 548, 'total_tokens': 1413, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjRpcX3Y1cbIXeJOuvblVhqWBhn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019cfa9a-39a1-7632-aeba-3bb12cbff572-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT a.Name\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nWHERE a.Name LIKE 'S%' OR a.Name LIKE 's%'\nGROUP BY a.ArtistId, a.Name\nORDER BY COUNT(t.TrackId) DESC\nLIMIT 1;"}, 'id': 'call_WjP6AaXZOAsoAMwVRh1Tgfsq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 548, 'output_tokens': 865, 'total_tokens': 1413, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#  ToolMessage(content="[('Smashing Pumpkins',)]", name='sql_query', id='4652d147-2df5-4a8f-9649-8ec8665ceeff', tool_call_id='call_WjP6AaXZOAsoAMwVRh1Tgfsq'),
#  AIMessage(content="The most popular artist starting with 'S' is: Smashing Pumpkins", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 658, 'total_tokens': 676, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DKIjaknZ7rXxwkEiSOrADZRCf6rc4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cfa9a-5d18-7861-bbe4-f4aca4a8d711-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 658, 'output_tokens': 18, 'total_tokens': 676, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
print(response["messages"][-3].tool_calls[0]['args']['query'])
# Out:
# SELECT a.Name
# FROM Artist a
# JOIN Album al ON al.ArtistId = a.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# WHERE a.Name LIKE 'S%' OR a.Name LIKE 's%'
# GROUP BY a.ArtistId, a.Name
# ORDER BY COUNT(t.TrackId) DESC
# LIMIT 1;
